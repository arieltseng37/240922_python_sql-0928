# %%
(1,3,5,7,9)

# %%
(1,3,5,7,9)
tu1=(1,3,5,7,9)
print(tu1[0])
print(tu1[1])
print(tu1[2])
print(tu1[3])
print(tu1[4])
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for value in tu1:
    print(value)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for  letter in "Hello! Word!":
    print(letter)
# Out:
# H
# e
# l
# l
# o
# !
#
# W
# o
# r
# d
# !

# %%
type(tu1)
# Out:
# tuple

# %%
##List

# %%
#建立List
li1=[2,4,6,8,10]
li1[0]
li1[1]
li1[2]
li1[3]
li1[4]
# Out:
# 10

# %%
for elemetn in li1:
    print(elemetn)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
type(li1)
# Out:
# list
